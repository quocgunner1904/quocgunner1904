# %% [markdown]
# # Recurrent Neural Network Homework
#
# This is the 4th assignment for CAP 4630 and we will implement a basic RNN network and an LSTM network with Keras to solve two problems. \
# You will use **"Tasks"** and **"Hints"** to finish the work. **(Total 100 points, including 15 bonus points)** \
# You may use Machine Learning libaries like Scikit-learn for data preprocessing.
#
# **Task Overview:**
# - Implement a basic RNN network to solve time series prediction
# - Implement an LSTM network to conduct sentiment analysis

# %% [markdown]
# ## 1 - Implement Basic RNN network with Keras to predict time series##
# ### 1.1 Prepare the data (17 Points)
#
# Prepare time series data for deep neural network training.
#
# **Tasks:**
# 1. Load the given train and test data: "train.txt" and "test.txt". **(5 Points)**
# 2. Generate the **TRAIN** and **TEST** labels. **(5 Points)**
# 3. Normalize the **TRAIN** and **TEST** data with sklearn function "MinMaxScaler". **(5 Points)**
# 4. **PRINT OUT** the **TEST** data and label. **(2 Points)**
#
# **Hints:**
# 1. The length of original train data is 113 which starts from **"1949-01"** to **"1958-05"**. The length of original test data is 29, which starts from **"1958-07"** to **"1960-11"**.
# 2. Set the data types of both train and test data to "float32".
# 3. When you prepared input data X (sequences) and oupt data Y (labels), please consider the following relationship:
#     - The sequence X should be the **past 12** datapoints in the time series, i.e., observation sequence with historical window of 12. You may check the time series data and think about the reason.
#     - The label Y should be the **next 1** datapoint in the time series (one point ahead prediction).
# 4. The first 3 **TRAIN** data and label should be:
#
# - trainX[0] = [[0.02203858 &nbsp; 0.03856748 &nbsp; 0.077135 &nbsp;  0.06887051 &nbsp; 0.04683197 &nbsp; 0.08539945 &nbsp; 0.12121212 &nbsp; 0.12121212 &nbsp; 0.08815429 &nbsp; 0.04132232 &nbsp; 0.    &nbsp; 0.03856748]]
# - trainY[0] = [0.03030303]
#
# - trianX[1] = [[0.03856748 &nbsp; 0.077135 &nbsp;  0.06887051 &nbsp; 0.04683197  &nbsp; 0.08539945  &nbsp; 0.12121212  &nbsp; 0.12121212  &nbsp; 0.08815429  &nbsp; 0.04132232  &nbsp; 0.     &nbsp;  0.03856748   &nbsp; 0.03030303]]
# - trainY[1] = [0.06060606]
#
# - trainX[2] =  [[0.077135 &nbsp;  0.06887051 &nbsp; 0.04683197 &nbsp; 0.08539945 &nbsp; 0.12121212 &nbsp; 0.12121212 &nbsp; 0.08815429 &nbsp; 0.04132232 &nbsp; 0.    &nbsp;     0.03856748 &nbsp; 0.03030303 &nbsp; 0.06060606]]
# - trainY[2] = [0.10192838]
#
# 5. Apply the MinMaxScaler to both the train and test data.\
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html
#
#
# 6. After the preparation with scaler fitting, the shapes of trainX, trainY, testX, and testY are as follows:\
# trainX.shape = (101, 1, 12)\
# trainY.shape = (101,)\
# testX.shape = (17, 1, 12)\
# testY.shape = (17,)

# %%
### Import Libraries ###

import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.layers 
import random
import numpy as np

### Set random seed to ensure deterministic results
import os
seed_value = 1
os.environ['PYTHONHASHSEED']=str(seed_value)
def reset_random_seeds():
   tf.random.set_seed(seed_value)
   np.random.seed(seed_value)
   random.seed(seed_value)
reset_random_seeds()

# %%
### Prepare and Preprocess Data Here ###
from pandas import read_csv

### Design a Function to Prepare Observation Sequences and Corresponding Labels ###

def create_dataset(dataset, look_back=12): # look_back is used to specify input sequence length
  dataX, dataY = [], []
  for i in range(len(dataset)-look_back):
    dataX.append(dataset[i:i+12,0]) 
    dataY.append(dataset[i+12:i+13, 0])
  return np.array(dataX), np.array(dataY)


### Train and Test Data Loading with float32 type ####
dataframe_train = read_csv('train.txt', usecols=[1], engine='python') # Read train.txt 
dataset_train = dataframe_train.values
dataset_train = dataset_train.astype('float32') # Specify the data type to 'float32'

dataframe_test = read_csv('test.txt', usecols=[1], engine='python') # Read test.txt 
dataset_test = dataframe_test.values
dataset_test = dataset_test.astype('float32') # Specify the data type to 'float32'

### Scale Training and Test Data to [0, 1] ###
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1)) # specify the scaler
train = scaler.fit_transform(dataset_train) # fit the scaler to the training data
test = scaler.fit_transform(dataset_test) # fit the scaler to the test data

### Training and Test Data Split ###
trainX, trainY = create_dataset(train, look_back=12)
testX, testY = create_dataset(test, look_back=12)

### Training and Test Data Reshape (to fit RNN input) ###
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
trainY = np.reshape(trainY, (trainY.shape[0]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
testY = np.reshape(testY, (testY.shape[0]))

# %%
### Print Out the TEST Data and Labels Here ###
print(testX)
print(testY)
# Out:
# [[[0.5801282  0.625      0.30128205 0.15705132 0.         0.08653843
#    0.16025639 0.1025641  0.3076923  0.27564108 0.3525641  0.5192307 ]]
#
#  [[0.625      0.30128205 0.15705132 0.         0.08653843 0.16025639
#    0.1025641  0.3076923  0.27564108 0.3525641  0.5192307  0.7628205 ]]
#
#  [[0.30128205 0.15705132 0.         0.08653843 0.16025639 0.1025641
#    0.3076923  0.27564108 0.3525641  0.5192307  0.7628205  0.798077  ]]
#
#  [[0.15705132 0.         0.08653843 0.16025639 0.1025641  0.3076923
#    0.27564108 0.3525641  0.5192307  0.7628205  0.798077   0.49038458]]
#
#  [[0.         0.08653843 0.16025639 0.1025641  0.3076923  0.27564108
#    0.3525641  0.5192307  0.7628205  0.798077   0.49038458 0.31089747]]
#
#  [[0.08653843 0.16025639 0.1025641  0.3076923  0.27564108 0.3525641
#    0.5192307  0.7628205  0.798077   0.49038458 0.31089747 0.16666663]]
#
#  [[0.16025639 0.1025641  0.3076923  0.27564108 0.3525641  0.5192307
#    0.7628205  0.798077   0.49038458 0.31089747 0.16666663 0.30448723]]
#
#  [[0.1025641  0.3076923  0.27564108 0.3525641  0.5192307  0.7628205
#    0.798077   0.49038458 0.31089747 0.16666663 0.30448723 0.34294868]]
#
#  [[0.3076923  0.27564108 0.3525641  0.5192307  0.7628205  0.798077
#    0.49038458 0.31089747 0.16666663 0.30448723 0.34294868 0.25961542]]
#
#  [[0.27564108 0.3525641  0.5192307  0.7628205  0.798077   0.49038458
#    0.31089747 0.16666663 0.30448723 0.34294868 0.25961542 0.34935904]]
#
#  [[0.3525641  0.5192307  0.7628205  0.798077   0.49038458 0.31089747
#    0.16666663 0.30448723 0.34294868 0.25961542 0.34935904 0.48397434]]
#
#  [[0.5192307  0.7628205  0.798077   0.49038458 0.31089747 0.16666663
#    0.30448723 0.34294868 0.25961542 0.34935904 0.48397434 0.5192307 ]]
#
#  [[0.7628205  0.798077   0.49038458 0.31089747 0.16666663 0.30448723
#    0.34294868 0.25961542 0.34935904 0.48397434 0.5192307  0.72115386]]
#
#  [[0.798077   0.49038458 0.31089747 0.16666663 0.30448723 0.34294868
#    0.25961542 0.34935904 0.48397434 0.5192307  0.72115386 1.        ]]
#
#  [[0.49038458 0.31089747 0.16666663 0.30448723 0.34294868 0.25961542
#    0.34935904 0.48397434 0.5192307  0.72115386 1.         0.94871795]]
#
#  [[0.31089747 0.16666663 0.30448723 0.34294868 0.25961542 0.34935904
#    0.48397434 0.5192307  0.72115386 1.         0.94871795 0.6346154 ]]
#
#  [[0.16666663 0.30448723 0.34294868 0.25961542 0.34935904 0.48397434
#    0.5192307  0.72115386 1.         0.94871795 0.6346154  0.48397434]]]
# [0.7628205  0.798077   0.49038458 0.31089747 0.16666663 0.30448723
#  0.34294868 0.25961542 0.34935904 0.48397434 0.5192307  0.72115386
#  1.         0.94871795 0.6346154  0.48397434 0.25641024]

# %% [markdown]
# ### 1.2 - Build the RNN model (20 Points) ##
#
#
# Build an RNN model with SimpleRNN cell.
#
# **Tasks:**
# 1. Build an RNN model with 1 RNN layer and 1 Dense layer.  **(10 Points)**
# 2. Compile the model. **(5 Points)**
# 3. Train the model for **1000** epochs with **batch_size = 10**. **(5 Points)**
#
# **Hints:**
# 1. You may consider **tensorflow.keras.layers.SimpleRNN(unit_size=4)** to specify RNN cells.
# 2. Use loss function = 'mean_squared_error' and select **Adam** optimizer with **learning_rate=0.005** and other default settings.
# 3. After first epoch, the train loss is changed to around **0.0912**.
# 4. The model summary is as follows:
# - Total params: 73
# - Trainable params: 73
# - Non-trainable params: 0

# %%
### Build the RNN Model ###
import keras
from keras.models import Sequential

keras.backend.clear_session()

model = Sequential() # Declare Sequential class and assign it to variable "model"
model.add(keras.layers.SimpleRNN(4)) # Add a simple RNN layer with unit_size=4 in the model 
model.add(keras.layers.Dense(1)) # Add a following Dense layer with units=1 in the model

# %%
### Compile the RNN Model  ###

opt = keras.optimizers.Adam(learning_rate=0.005)
model.compile(loss="mean_squared_error", optimizer=opt) # model compiled with mean_squared_error loss and adam optimizer

# %%
### Train the RNN Model  ###

model.fit(trainX, trainY, batch_size=10, epochs=1000) # model fit with epoch=1000, batch_size=10; verbose=2 is optional.
model.summary() # print out model structure with model.summary()
# Out:
# Epoch 1/1000
# 11/11 [==============================] - 1s 3ms/step - loss: 0.1295
# Epoch 2/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0335
# Epoch 3/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0260
# Epoch 4/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0163
# Epoch 5/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0167
# Epoch 6/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0187
# Epoch 7/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0155
# Epoch 8/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0138
# Epoch 9/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0122
# Epoch 10/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0106
# Epoch 11/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0073
# Epoch 12/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0086
# Epoch 13/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0082
# Epoch 14/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0076
# Epoch 15/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0059
# Epoch 16/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0058
# Epoch 17/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0059
# Epoch 18/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0047
# Epoch 19/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0045
# Epoch 20/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0042
# Epoch 21/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0037
# Epoch 22/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 23/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0037
# Epoch 24/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0037
# Epoch 25/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 26/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0037
# Epoch 27/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 28/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 29/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0026
# Epoch 30/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0026
# Epoch 31/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0022
# Epoch 32/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0022
# Epoch 33/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0025
# Epoch 34/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0024
# Epoch 35/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0021
# Epoch 36/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0021
# Epoch 37/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0022
# Epoch 38/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0023
# Epoch 39/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0029
# Epoch 40/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 41/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0022
# Epoch 42/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 43/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 44/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0019
# Epoch 45/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0020
# Epoch 46/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0017
# Epoch 47/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0022
# Epoch 48/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 49/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 50/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0020
# Epoch 51/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0017
# Epoch 52/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0018
# Epoch 53/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0015
# Epoch 54/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 55/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 56/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 57/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 58/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 59/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 60/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 61/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 62/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 63/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 64/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 65/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 66/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 67/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 68/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0019
# Epoch 69/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0018
# Epoch 70/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 71/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 72/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 73/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 74/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 75/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 76/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 77/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 78/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 79/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 80/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 81/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 82/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 83/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 84/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0023
# Epoch 85/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 86/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 87/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 88/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 89/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 90/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0015
# Epoch 91/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 92/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 93/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 94/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 95/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 96/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 97/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 98/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 99/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 100/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 101/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 102/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 103/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 104/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 105/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 106/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 107/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 108/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 109/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 110/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 111/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 112/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 113/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 114/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 115/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 116/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 117/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 118/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 119/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 120/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0014
# Epoch 121/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 122/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 123/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 124/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 125/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 126/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 127/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 128/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 129/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0022
# Epoch 130/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 131/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 132/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.8320e-04
# Epoch 133/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0018
# Epoch 134/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 135/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 136/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 137/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 138/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 139/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 140/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.2472e-04
# Epoch 141/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 142/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 143/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 144/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 8.5697e-04
# Epoch 145/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 146/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 147/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 148/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 149/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 150/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 151/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 152/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 153/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 154/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.7474e-04
# Epoch 155/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 156/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 157/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.9535e-04
# Epoch 158/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 159/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.9523e-04
# Epoch 160/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 161/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 162/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0026
# Epoch 163/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0018
# Epoch 164/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 165/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 166/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 167/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 168/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 169/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 170/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 171/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 172/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 173/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 174/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 175/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 176/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 177/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0020
# Epoch 178/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0018
# Epoch 179/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 180/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 181/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 182/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0019
# Epoch 183/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 184/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 185/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 8.5180e-04
# Epoch 186/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 187/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 188/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 189/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 190/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0018
# Epoch 191/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 192/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 193/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 194/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.9889e-04
# Epoch 195/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 196/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 197/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 198/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 199/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 200/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 201/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0022
# Epoch 202/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 203/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 204/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 205/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 206/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 207/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.4358e-04
# Epoch 208/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 209/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.4243e-04
# Epoch 210/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 211/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 212/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0017
# Epoch 213/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 214/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 215/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 216/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 217/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.6671e-04
# Epoch 218/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0019
# Epoch 219/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 220/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 221/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 222/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0014
# Epoch 223/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 224/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 225/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 226/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 227/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 8.8464e-04
# Epoch 228/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 229/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 230/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 231/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 232/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 233/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 234/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 235/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 236/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 237/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 238/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 239/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 240/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 241/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 242/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 243/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 244/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 245/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 246/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 247/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 248/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 249/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 250/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 251/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.4183e-04
# Epoch 252/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 8.3426e-04
# Epoch 253/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.8702e-04
# Epoch 254/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 255/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 256/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 257/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 258/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.1145e-04
# Epoch 259/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 260/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 261/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 262/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 263/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 264/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 265/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 266/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 8.9356e-04
# Epoch 267/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 268/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 269/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 270/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.8789e-04
# Epoch 271/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 272/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.5188e-04
# Epoch 273/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 274/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 275/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 8.6469e-04
# Epoch 276/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 277/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 278/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 279/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 280/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 281/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.3091e-04
# Epoch 282/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 283/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 284/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0019
# Epoch 285/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0021
# Epoch 286/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 287/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0021
# Epoch 288/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 289/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0016
# Epoch 290/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 291/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 292/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.8404e-04
# Epoch 293/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 294/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 295/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 296/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 297/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 298/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 8.9407e-04
# Epoch 299/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 300/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 301/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 302/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 303/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 304/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 305/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.0451e-04
# Epoch 306/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 8.2729e-04
# Epoch 307/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.9182e-04
# Epoch 308/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 309/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 310/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 311/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.7879e-04
# Epoch 312/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 313/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 314/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 315/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 316/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 317/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 318/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 319/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 320/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.0461e-04
# Epoch 321/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0021
# Epoch 322/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 323/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 324/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 325/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.9270e-04
# Epoch 326/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.2608e-04
# Epoch 327/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 328/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 9.6952e-04
# Epoch 329/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 330/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 331/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 332/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 333/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 9.5297e-04
# Epoch 334/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 335/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.8377e-04
# Epoch 336/1000
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 337/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 338/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0022
# Epoch 339/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 340/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 341/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 342/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.8171e-04
# Epoch 343/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.7848e-04
# Epoch 344/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 345/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 346/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 347/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.4702e-04
# Epoch 348/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 349/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0018
# Epoch 350/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0021
# Epoch 351/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 352/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 353/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 354/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 355/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.7633e-04
# Epoch 356/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 357/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 358/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 359/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 360/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 8.3225e-04
# Epoch 361/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 362/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 363/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 364/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.6450e-04
# Epoch 365/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 366/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 367/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 8.5926e-04
# Epoch 368/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 369/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 370/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 371/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 372/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.7774e-04
# Epoch 373/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 374/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0016
# Epoch 375/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.6529e-04
# Epoch 376/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.3493e-04
# Epoch 377/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0014
# Epoch 378/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 379/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 380/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 381/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 382/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 383/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 384/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.0937e-04
# Epoch 385/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 386/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.2860e-04
# Epoch 387/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 388/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 389/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.4364e-04
# Epoch 390/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 391/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 392/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 393/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0014
# Epoch 394/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 395/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 396/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 8.4480e-04
# Epoch 397/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 398/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 399/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 400/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 401/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 9.0679e-04
# Epoch 402/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 9.4923e-04
# Epoch 403/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 404/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 8.6314e-04
# Epoch 405/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 406/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 407/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 408/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.9883e-04
# Epoch 409/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 410/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 411/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 412/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 413/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0019
# Epoch 414/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.0752e-04
# Epoch 415/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0014
# Epoch 416/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 417/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0028
# Epoch 418/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 419/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 420/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 421/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 422/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 423/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 424/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 425/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 426/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 427/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 428/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 8.5599e-04
# Epoch 429/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.9048e-04
# Epoch 430/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 431/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 432/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 433/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0019
# Epoch 434/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 435/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.1369e-04
# Epoch 436/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 437/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 438/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 9.8856e-04
# Epoch 439/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 440/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 441/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.9585e-04
# Epoch 442/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.5330e-04
# Epoch 443/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 444/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 445/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 446/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 447/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 448/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 449/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 450/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.8015e-04
# Epoch 451/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 7.6493e-04
# Epoch 452/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 453/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 454/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 455/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 456/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 457/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 458/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 459/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 460/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 461/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 8.9177e-04
# Epoch 462/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 463/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 464/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.0241e-04
# Epoch 465/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 466/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 467/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 468/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 469/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 470/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 471/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 472/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0021
# Epoch 473/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.2353e-04
# Epoch 474/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 475/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.6634e-04
# Epoch 476/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 8.2527e-04
# Epoch 477/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 478/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 479/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0014
# Epoch 480/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 481/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0016
# Epoch 482/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 483/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 484/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 8.6353e-04
# Epoch 485/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.0516e-04
# Epoch 486/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 487/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0014
# Epoch 488/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 489/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 490/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 9.7645e-04
# Epoch 491/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 8.3917e-04
# Epoch 492/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 493/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 8.3308e-04
# Epoch 494/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.5018e-04
# Epoch 495/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 496/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 497/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 498/1000
# 11/11 [==============================] - 0s 5ms/step - loss: 8.7561e-04
# Epoch 499/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 500/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 501/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 502/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 503/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 504/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 505/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0014
# Epoch 506/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 507/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.4870e-04
# Epoch 508/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 9.9471e-04
# Epoch 509/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.2603e-04
# Epoch 510/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 511/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 512/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 8.2842e-04
# Epoch 513/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.8203e-04
# Epoch 514/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 515/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 516/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 8.0116e-04
# Epoch 517/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 518/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 519/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0015
# Epoch 520/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 521/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 522/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 523/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0015
# Epoch 524/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 525/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0017
# Epoch 526/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 527/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 7.7001e-04
# Epoch 528/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 8.6022e-04
# Epoch 529/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 530/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 531/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 532/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 533/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.5294e-04
# Epoch 534/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 9.7601e-04
# Epoch 535/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 9.2418e-04
# Epoch 536/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 537/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 8.7071e-04
# Epoch 538/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 539/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 7.9267e-04
# Epoch 540/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 541/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 542/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0021
# Epoch 543/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 544/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 545/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 546/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 8.5239e-04
# Epoch 547/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.7622e-04
# Epoch 548/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 549/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 550/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 551/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.2928e-04
# Epoch 552/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 553/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.4838e-04
# Epoch 554/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 555/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 8.5168e-04
# Epoch 556/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 8.3455e-04
# Epoch 557/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 558/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 559/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 8.7789e-04
# Epoch 560/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 561/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 8.7605e-04
# Epoch 562/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 563/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 564/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 8.7651e-04
# Epoch 565/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 566/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 567/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.9942e-04
# Epoch 568/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.8496e-04
# Epoch 569/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 570/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 571/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.1934e-04
# Epoch 572/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 573/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 574/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 575/1000
# ...
# Epoch 820/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 8.3495e-04
# Epoch 821/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 9.9120e-04
# Epoch 822/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 823/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 9.3289e-04
# Epoch 824/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 8.5264e-04
# Epoch 825/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.4185e-04
# Epoch 826/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 827/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 828/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 8.6045e-04
# Epoch 829/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0014
# Epoch 830/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 831/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 8.4723e-04
# Epoch 832/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 833/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.8580e-04
# Epoch 834/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 9.1692e-04
# Epoch 835/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 8.6049e-04
# Epoch 836/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 8.2612e-04
# Epoch 837/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 838/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 839/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 840/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 9.7248e-04
# Epoch 841/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 9.0765e-04
# Epoch 842/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 843/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 7.7550e-04
# Epoch 844/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0015
# Epoch 845/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 846/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 847/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 848/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 7.8079e-04
# Epoch 849/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0026
# Epoch 850/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0014
# Epoch 851/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 852/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 853/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 854/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 855/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 856/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 857/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 858/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 8.4153e-04
# Epoch 859/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 860/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 9.1238e-04
# Epoch 861/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 9.1453e-04
# Epoch 862/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0014
# Epoch 863/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 9.1091e-04
# Epoch 864/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 9.4340e-04
# Epoch 865/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 866/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 867/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 868/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 9.1498e-04
# Epoch 869/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 870/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 871/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 872/1000
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 873/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 874/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 875/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0014
# Epoch 876/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 7.2199e-04
# Epoch 877/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 878/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 879/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 880/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 8.4471e-04
# Epoch 881/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 882/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 8.9564e-04
# Epoch 883/1000
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0016
# Epoch 884/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 885/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 886/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 8.9293e-04
# Epoch 887/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 7.9522e-04
# Epoch 888/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 9.7034e-04
# Epoch 889/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 8.2476e-04
# Epoch 890/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0017
# Epoch 891/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 9.6138e-04
# Epoch 892/1000
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0010
# Epoch 893/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 894/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 895/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 8.4808e-04
# Epoch 896/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 8.4392e-04
# Epoch 897/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 7.6511e-04
# Epoch 898/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 899/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 8.7850e-04
# Epoch 900/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 901/1000
# 11/11 [==============================] - 0s 5ms/step - loss: 7.0284e-04
# Epoch 902/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 8.0881e-04
# Epoch 903/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 8.1942e-04
# Epoch 904/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 7.7942e-04
# Epoch 905/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 9.2591e-04
# Epoch 906/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 907/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 908/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.4968e-04
# Epoch 909/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 910/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 9.7236e-04
# Epoch 911/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 912/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 913/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0014
# Epoch 914/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0015
# Epoch 915/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 916/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 8.1922e-04
# Epoch 917/1000
# 11/11 [==============================] - 0s 5ms/step - loss: 9.3094e-04
# Epoch 918/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 9.2922e-04
# Epoch 919/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 920/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 921/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 922/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 923/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 924/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 925/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.7474e-04
# Epoch 926/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 927/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 9.1368e-04
# Epoch 928/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 7.5992e-04
# Epoch 929/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 7.7407e-04
# Epoch 930/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0016
# Epoch 931/1000
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 932/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 933/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 934/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 9.8866e-04
# Epoch 935/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 936/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 8.9641e-04
# Epoch 937/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 938/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 939/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 940/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 9.5236e-04
# Epoch 941/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 942/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.0617e-04
# Epoch 943/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 944/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 9.2955e-04
# Epoch 945/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 9.0523e-04
# Epoch 946/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 9.3989e-04
# Epoch 947/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 9.8819e-04
# Epoch 948/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 9.8286e-04
# Epoch 949/1000
# 11/11 [==============================] - 0s 5ms/step - loss: 8.3125e-04
# Epoch 950/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 951/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 8.5271e-04
# Epoch 952/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0014
# Epoch 953/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 8.2457e-04
# Epoch 954/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 8.4728e-04
# Epoch 955/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 9.9315e-04
# Epoch 956/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 7.9036e-04
# Epoch 957/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 958/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 8.5292e-04
# Epoch 959/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 960/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 961/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 8.6154e-04
# Epoch 962/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 7.5476e-04
# Epoch 963/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 964/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 9.2289e-04
# Epoch 965/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 8.8662e-04
# Epoch 966/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 7.6827e-04
# Epoch 967/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.1228e-04
# Epoch 968/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 969/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 9.1753e-04
# Epoch 970/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 971/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 9.9764e-04
# Epoch 972/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 8.8943e-04
# Epoch 973/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 974/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 9.4322e-04
# Epoch 975/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 976/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 977/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 978/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 9.7333e-04
# Epoch 979/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 980/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 981/1000
# 11/11 [==============================] - 0s 5ms/step - loss: 8.1159e-04
# Epoch 982/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 7.9180e-04
# Epoch 983/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 7.7010e-04
# Epoch 984/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 8.6254e-04
# Epoch 985/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 6.7427e-04
# Epoch 986/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 8.0838e-04
# Epoch 987/1000
# 11/11 [==============================] - 0s 5ms/step - loss: 8.0272e-04
# Epoch 988/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 989/1000
# 11/11 [==============================] - 0s 5ms/step - loss: 8.5992e-04
# Epoch 990/1000
# 11/11 [==============================] - 0s 5ms/step - loss: 9.7047e-04
# Epoch 991/1000
# 11/11 [==============================] - 0s 5ms/step - loss: 8.6488e-04
# Epoch 992/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 7.5594e-04
# Epoch 993/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 994/1000
# 11/11 [==============================] - 0s 5ms/step - loss: 8.5126e-04
# Epoch 995/1000
# 11/11 [==============================] - 0s 5ms/step - loss: 9.9551e-04
# Epoch 996/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 8.6513e-04
# Epoch 997/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 998/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 7.7932e-04
# Epoch 999/1000
# 11/11 [==============================] - 0s 4ms/step - loss: 9.4928e-04
# Epoch 1000/1000
# 11/11 [==============================] - 0s 3ms/step - loss: 8.7434e-04
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn (SimpleRNN)       (None, 4)                 68
# _________________________________________________________________
# dense (Dense)                (None, 1)                 5
# =================================================================
# Total params: 73
# Trainable params: 73
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 1.3 Evaluate Predictive Model Performance (10 Points)
#
# Predict datapoints with the observed datapoints and trained model.
#
# **Tasks:**
# 1. Do direct prediction on train and test datapoints with the obtained model in section 1.2. **(2 Points)**
# 2. Scale the prediction results back to original representation with the scaler. **(3 Points)**
# 3. Calculate root mean squared error (RMSE) and **print out** the error for **both TRAIN and TEST**. **(3 Points)**
# 4. **Plot** the **TEST** label and prediction. **(2 Points)**
#
#
# **Hints:**
# 1. Scale back the predictions with the build-in function "scaler.inverse_transform".\
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html#sklearn.preprocessing.MinMaxScaler.inverse_transform
# 2. For validation: Train Score: **~10.92 RMSE** Test Score: **~27.70 RMSE**
# 3. The plot for validation is shown below (observation test data are blue and prediction results are orange):
#
# ![image.png](data:image/png;base64,...)

# %%
### Make Predictions ###

trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# %%
### Scale Back Predictions ###

trainPredict = scaler.inverse_transform(trainPredict) # scale train prediction back with scaler.inverse_transform()
trainY = scaler.inverse_transform([trainY])  # scale train labels back with scaler.inverse_transform()

testPredict = scaler.inverse_transform(testPredict) # scale test prediction back with scaler.inverse_transform()
testY = scaler.inverse_transform([testY]) # scale test labels back with scaler.inverse_transform()

# %%
### Calculate Root Mean Squared Error (RMSE) ###
import math
from sklearn.metrics import mean_squared_error # Import mean_squared_error from sklearn.metrics

trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0])) 
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 9.38 RMSE
# Test Score: 22.14 RMSE

# %%
### Plot Observation Data and Prediction Results with TEST dataset ###

import matplotlib.pyplot as plt
plt.plot(testY[0]) # Plot Observations in Test Set
plt.plot(testPredict) # Plot Predictions in Test Set

plt.show()

# %% [markdown]
# ## 2 - Build an LSTM model to conduct sentiment analysis ##
#
# ### 2.1 Prepare the data (13 Points) ###
#
# Prepare IMDB data for reccurent neural network training.
#
# **Tasks:**
# 1. Load the data from IMDB review dataset and **print out** the lengths of sequences. **(3 Points)**
# 2. Preprocess review data to meet the network input requirement by specifying **number of words=1000**, setting **the analysis length of the review = 100**, and **padding the input sequences**. **(10 Points)**
#
# **Hints:**
# 1. You may load the IMDB data with keras.datasets.imdb.load_data(num_words=max_features). Here. max_features is set to **1000**.
# 2. You may use keras.preprocessing.sequence.pad_sequences(x_train, maxlen) to pad the input sequences and set maxlen to **100**.
#
# **Note:**\
# We train the built LSTM-based model with ALL training data; the **validation set** (aka **development set**) is set with the **testing set** for model evaluation. This split is common in the application with limited sampled observation data, like NLP problems.

# %%
import tensorflow as tf
import tensorflow.keras as keras
from keras import layers
import random
import numpy as np


### Set random seed to ensure deterministic results
import os
seed_value = 1
os.environ['PYTHONHASHSEED']=str(seed_value)
def reset_random_seeds():
   tf.random.set_seed(seed_value)
   np.random.seed(seed_value)
   random.seed(seed_value)

reset_random_seeds() # randomly set initial data

# %%
# Prepare the data here

max_features = 1000 # Only consider the top 1k words
maxlen = 100 # Only consider the first 100 words of each movie review

(x_train, y_train), (x_val, y_val) = keras.datasets.imdb.load_data(num_words=1000) # load IMDB data with specified num_words = 1000; testing set is set to validation set.
print(len(x_train), "Training sequences")
print(len(x_val), "Validation sequences")
x_train = keras.preprocessing.sequence.pad_sequences(x_train, maxlen) # Pad IMDB training data with specified maxlen=100
x_val = keras.preprocessing.sequence.pad_sequences(x_val, maxlen) # Pad IMDB validation data with specified maxlen=100
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17465344/17464789 [==============================] - 0s 0us/step
# <string>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/datasets/imdb.py:159: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_train, y_train = np.array(xs[:idx]), np.array(labels[:idx])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/datasets/imdb.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_test, y_test = np.array(xs[idx:]), np.array(labels[idx:])
# 25000 Training sequences
# 25000 Validation sequences

# %% [markdown]
# ### 2.2 - Design and train LSTM model (25 Points) ###
#
# Build an LSTM model.
#
# **Tasks:**
# 1. Build the LSTM model with **1 embedding layer**, **1 LSTM layer**, and **1 Dense layer**. **Print out** model summary. The embedding vector is specified with the dimension of **8**. **(10 Points)**
# 2. Compile the LSTM model with **Adam** optimizer, **binary_crossentropy** loss function, and **accuracy** metrics. **(5 Points)**
# 3. Train the LSTM model with **batch_size=64 for 10 epochs** and report **training and validation accuracies over epochs**. **(5 Points)**
# 4. **Print out** best validation accuracy. **(5 Points)**
#
#
#
# **Hints:**
# 1. Set input dimension to **1000** and output dimension to **8** for embedding layer.
# 2. Set **unit_size=8** for LSTM layer.
# 3. Set activation function to **sigmoid** for Dense layer.
# 4. For validation: the outputs for first epoch should be close to（but maybe not exactly following） the statistics below:\
# - **-loss: ~0.6402 - accuracy: ~0.6187 - val_loss: ~0.4645 - val_accuracy: ~0.7995**
# 5. The model summary is as follows:
# - Total params: 8,553
# - Trainable params: 8,553
# - Non-trainable params: 0
#
# **Useful Reference:**
# 1. https://keras.io/examples/nlp/bidirectional_lstm_imdb/

# %%
### Model design with Embedding and LSTM layers ####
inputs = keras.Input(shape=(None,), dtype="int32") # This is an easy way to set an adaptive length for input sequence
x = layers.Embedding(max_features,8)(inputs) # Embed data in an 8-dimensional vector
x = layers.LSTM(8)(x) # Add 1st layer of LSTM with 8 hidden states (aka units)
outputs = layers.Dense(1, activation="sigmoid")(x) # Add a classifier with units=1 and activation="sigmoid"

### Clear cached model to refresh memory and build new model for training ###
keras.backend.clear_session() # Clear cached model
model = keras.Model(inputs, outputs) # Build new keras model
model.summary() # Print out model summary

model.compile("adam", "binary_crossentropy", metrics=["accuracy"]) # Compile built model with "adam", "binary_crossentropy", and metrics=["accuracy"]
model.fit(x_train, y_train, batch_size=64, epochs=10, validation_data=(x_val, y_val)) # Train the compiled model with model.fit()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, None)]            0
# _________________________________________________________________
# embedding (Embedding)        (None, None, 8)           8000
# _________________________________________________________________
# lstm (LSTM)                  (None, 8)                 544
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 8,553
# Trainable params: 8,553
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 34s 11ms/step - loss: 0.6402 - accuracy: 0.6187 - val_loss: 0.4645 - val_accuracy: 0.7995
# Epoch 2/10
# 391/391 [==============================] - 4s 10ms/step - loss: 0.4172 - accuracy: 0.8151 - val_loss: 0.4004 - val_accuracy: 0.8186
# Epoch 3/10
# 391/391 [==============================] - 4s 10ms/step - loss: 0.3846 - accuracy: 0.8316 - val_loss: 0.3840 - val_accuracy: 0.8281
# Epoch 4/10
# 391/391 [==============================] - 4s 10ms/step - loss: 0.3596 - accuracy: 0.8449 - val_loss: 0.3839 - val_accuracy: 0.8259
# Epoch 5/10
# 391/391 [==============================] - 4s 10ms/step - loss: 0.3593 - accuracy: 0.8449 - val_loss: 0.3816 - val_accuracy: 0.8282
# Epoch 6/10
# 391/391 [==============================] - 4s 9ms/step - loss: 0.3531 - accuracy: 0.8451 - val_loss: 0.4290 - val_accuracy: 0.8160
# Epoch 7/10
# 391/391 [==============================] - 4s 9ms/step - loss: 0.3489 - accuracy: 0.8477 - val_loss: 0.3723 - val_accuracy: 0.8311
# Epoch 8/10
# 391/391 [==============================] - 4s 10ms/step - loss: 0.3446 - accuracy: 0.8490 - val_loss: 0.3741 - val_accuracy: 0.8295
# Epoch 9/10
# 391/391 [==============================] - 4s 10ms/step - loss: 0.3353 - accuracy: 0.8519 - val_loss: 0.3903 - val_accuracy: 0.8314
# Epoch 10/10
# 391/391 [==============================] - 4s 10ms/step - loss: 0.3337 - accuracy: 0.8551 - val_loss: 0.3808 - val_accuracy: 0.8310

# %% [markdown]
# ### 2.3 - LSTM hyperparameter tuning (Bonus 15 Points) ###
#
# Boost the performance of obtained LSTM (aka vanilla model) by hyperparameter tuning.
#
# **Tasks:**
# Note:
# - All modificiations are directly conducted based on the vanilla model above (from 2.2).
# - For each scenario, **report <span style="color:red"> BEST Validation Accuracy </span> and generate Training/Validation <span style="color:red"> Accuracy plots over epochs</span>**. You may just paste the plot figures in the cells with **Markdown mode**, or leave the result after running. **Make sure it is already correctly shown in your submitted file.**
# 1.  Scenario 1 (**5 points**):
#     - Add one additional LSTM layer (totally 2 LSTM layers).
#     - Modify the embedding dimension to 16.
#     - Modify the units of LSTM to 16.
# 2. Scenario 2 (**5 points**)
#     - Add one additional LSTM layer (totally 2 LSTM layers).
#     - Modify the embedding dimension to 128.
#     - Modify the units of LSTM to 128.
# 3. Scenario 3 (**5 points**)
#     - Add one additional LSTM layer (totally 2 LSTM layers).
#     - Modify the embedding dimension to 128.
#     - Modify the units of LSTM to 128.
#     - Increase analysis length for review data to maxlen = 200
#
# **Hints:**
# For validation: the outputs for first epoch should be close to （but maybe not exactly following） the statistics below:
# - Scenario 1: **loss: ~0.5839 - accuracy: ~0.6524 - val_loss: ~0.4079 - val_accuracy: ~0.8198**
# - Scenario 2: **loss: ~0.5572 - accuracy: ~0.6911 - val_loss: ~0.3953 - val_accuracy: ~0.8244**
# - Scenario 3: **loss: ~0.5605 - accuracy: ~0.6914 - val_loss: ~0.3402 - val_accuracy: ~0.8560**
#
# - Summary of Model 1: Total params: 20,241; Trainable params: 20,241; Non-trainable params: 0
# - Summary of Model 2: Total params: 391,297; Trainable params: 391,297; Non-trainable params: 0
# - Summary of Model 3: Total params: 391,297; Trainable params: 391,297; Non-trainable params: 0
#
# You may follow the example from the reference below to add additional LSTM layer.
#
# **Useful Reference:**
# 1. https://keras.io/examples/nlp/bidirectional_lstm_imdb/

# %%
########################### Scenario 1 ###########################
##################################################################

### Set random seed to ensure deterministic results ###
import os
seed_value = 1
os.environ['PYTHONHASHSEED']=str(seed_value)
def reset_random_seeds():
   tf.random.set_seed(seed_value)
   np.random.seed(seed_value)
   random.seed(seed_value)

reset_random_seeds() # randomly set initial data

max_features = 1000 # Only consider the top 1k words
maxlen = 100 # Only consider the first 100 words of each movie review

### Model design with Embedding and LSTM layers ####
inputs = keras.Input(shape=(None,), dtype="int32") # This is an easy way to set an adaptive length for input sequence
x = layers.Embedding(max_features, 16)(inputs) # Embed data in a 16-dimensional vector
x = layers.LSTM(16, return_sequences="true")(x) # Add 1st layer of LSTM with 16 hidden states (aka units); set return_sequences=true.
x = layers.LSTM(16)(x) # Add 2nd layer of LSTM with 16 hidden states (aka units)
outputs = layers.Dense(1, activation="sigmoid")(x) # Add a classifier with units=1 and activation="sigmoid"

### Clear cached model to refresh memory and build new model for training ###
keras.backend.clear_session() # Clear cached model
model = keras.Model(inputs, outputs) # Build new keras model
model.summary() # Print out model summary

model.compile("adam", "binary_crossentropy", metrics=["accuracy"]) # Compile built model with "adam", "binary_crossentropy", and metrics=["accuracy"]
model.fit(x_train, y_train, batch_size=64, epochs=10, validation_data=(x_val, y_val)) # Train the compiled model using model.fit() with batch_size=64, epochs=10, and validation_data=(x_val, y_val)
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, None)]            0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, None, 16)          16000
# _________________________________________________________________
# lstm (LSTM)                  (None, None, 16)          2112
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 16)                2112
# _________________________________________________________________
# dense (Dense)                (None, 1)                 17
# =================================================================
# Total params: 20,241
# Trainable params: 20,241
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 9s 17ms/step - loss: 0.5839 - accuracy: 0.6524 - val_loss: 0.4079 - val_accuracy: 0.8198
# Epoch 2/10
# 391/391 [==============================] - 6s 15ms/step - loss: 0.3826 - accuracy: 0.8316 - val_loss: 0.3844 - val_accuracy: 0.8242
# Epoch 3/10
# 391/391 [==============================] - 6s 15ms/step - loss: 0.3674 - accuracy: 0.8394 - val_loss: 0.3692 - val_accuracy: 0.8333
# Epoch 4/10
# 391/391 [==============================] - 6s 15ms/step - loss: 0.3461 - accuracy: 0.8480 - val_loss: 0.3798 - val_accuracy: 0.8257
# Epoch 5/10
# 391/391 [==============================] - 6s 15ms/step - loss: 0.3416 - accuracy: 0.8476 - val_loss: 0.3665 - val_accuracy: 0.8338
# Epoch 6/10
# 391/391 [==============================] - 6s 15ms/step - loss: 0.3268 - accuracy: 0.8559 - val_loss: 0.4104 - val_accuracy: 0.8247
# Epoch 7/10
# 391/391 [==============================] - 6s 15ms/step - loss: 0.3190 - accuracy: 0.8581 - val_loss: 0.3680 - val_accuracy: 0.8325
# Epoch 8/10
# 391/391 [==============================] - 6s 15ms/step - loss: 0.3153 - accuracy: 0.8623 - val_loss: 0.3659 - val_accuracy: 0.8334
# Epoch 9/10
# 391/391 [==============================] - 6s 15ms/step - loss: 0.3065 - accuracy: 0.8620 - val_loss: 0.3800 - val_accuracy: 0.8334
# Epoch 10/10
# 391/391 [==============================] - 6s 15ms/step - loss: 0.2991 - accuracy: 0.8707 - val_loss: 0.3928 - val_accuracy: 0.8343

# %%
########################### Scenario 2 ###########################
##################################################################

### Set random seed to ensure deterministic results ###
import os
seed_value = 1
os.environ['PYTHONHASHSEED']=str(seed_value)
def reset_random_seeds():
   tf.random.set_seed(seed_value)
   np.random.seed(seed_value)
   random.seed(seed_value)

reset_random_seeds() # randomly set initial data

max_features = 1000 # Only consider the top 1k words
maxlen = 100 # Only consider the first 100 words of each movie review

### Model design with Embedding and LSTM layers ####
inputs = keras.Input(shape=(None,), dtype="int32") # This is an easy way to set an adaptive length for input sequence
x = layers.Embedding(max_features, 128)(inputs) # Embed data in a 128-dimensional vector
x = layers.LSTM(128, return_sequences="true")(x) # Add 1st layer of LSTM with 128 hidden states (aka units); set return_sequences=true.
x = layers.LSTM(128)(x) # Add 2nd layer of LSTM with 128 hidden states (aka units)
outputs = layers.Dense(1, activation="sigmoid")(x) # Add a classifier with units=1 and activation="sigmoid"

### Clear cached model to refresh memory and build new model for training ###
keras.backend.clear_session() # Clear cached model
model = keras.Model(inputs, outputs) # Build new keras model
model.summary() # Print out model summary

model.compile("adam", "binary_crossentropy", metrics=["accuracy"]) # Compile built model with "adam", "binary_crossentropy", and metrics=["accuracy"]
model.fit(x_train, y_train, batch_size=64, epochs=10, validation_data=(x_val, y_val)) # Train the compiled model using model.fit() with batch_size=64, epochs=10, and validation_data=(x_val, y_val)
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, None)]            0
# _________________________________________________________________
# embedding (Embedding)        (None, None, 128)         128000
# _________________________________________________________________
# lstm (LSTM)                  (None, None, 128)         131584
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dense (Dense)                (None, 1)                 129
# =================================================================
# Total params: 391,297
# Trainable params: 391,297
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 12s 25ms/step - loss: 0.5556 - accuracy: 0.6917 - val_loss: 0.3933 - val_accuracy: 0.8267
# Epoch 2/10
# 391/391 [==============================] - 9s 24ms/step - loss: 0.3785 - accuracy: 0.8316 - val_loss: 0.3718 - val_accuracy: 0.8310
# Epoch 3/10
# 391/391 [==============================] - 9s 23ms/step - loss: 0.3540 - accuracy: 0.8431 - val_loss: 0.3689 - val_accuracy: 0.8342
# Epoch 4/10
# 391/391 [==============================] - 9s 23ms/step - loss: 0.3282 - accuracy: 0.8565 - val_loss: 0.3648 - val_accuracy: 0.8399
# Epoch 5/10
# 391/391 [==============================] - 9s 23ms/step - loss: 0.3073 - accuracy: 0.8665 - val_loss: 0.3566 - val_accuracy: 0.8447
# Epoch 6/10
# 391/391 [==============================] - 9s 23ms/step - loss: 0.2831 - accuracy: 0.8829 - val_loss: 0.3615 - val_accuracy: 0.8388
# Epoch 7/10
# 391/391 [==============================] - 9s 23ms/step - loss: 0.2703 - accuracy: 0.8908 - val_loss: 0.3623 - val_accuracy: 0.8373
# Epoch 8/10
# 391/391 [==============================] - 9s 24ms/step - loss: 0.2523 - accuracy: 0.8983 - val_loss: 0.3775 - val_accuracy: 0.8409
# Epoch 9/10
# 391/391 [==============================] - 9s 23ms/step - loss: 0.2419 - accuracy: 0.9003 - val_loss: 0.3949 - val_accuracy: 0.8292
# Epoch 10/10
# 391/391 [==============================] - 9s 24ms/step - loss: 0.2186 - accuracy: 0.9138 - val_loss: 0.4023 - val_accuracy: 0.8316

# %%
########################### Scenario 3 ###########################
##################################################################

### Set random seed to ensure deterministic results ###
import os
seed_value = 1
os.environ['PYTHONHASHSEED']=str(seed_value)
def reset_random_seeds():
   tf.random.set_seed(seed_value)
   np.random.seed(seed_value)
   random.seed(seed_value)

reset_random_seeds() # randomly set initial data

max_features = 1000 # Only consider the top 1k words
maxlen = 200 # Only consider the first 200 words of each movie review

### Model design with Embedding and LSTM layers ####
inputs = keras.Input(shape=(None,), dtype="int32") # This is an easy way to set an adaptive length for input sequence
x = layers.Embedding(max_features, 128)(inputs) # Embed data in a 128-dimensional vector
x = layers.LSTM(128, return_sequences="true")(x) # Add 1st layer of LSTM with 128 hidden states (aka units); set return_sequences=true.
x = layers.LSTM(128)(x) # Add 2nd layer of LSTM with 128 hidden states (aka units)
outputs = layers.Dense(1, activation="sigmoid")(x) # Add a classifier with units=1 and activation="sigmoid"

### Clear cached model to refresh memory and build new model for training ###
keras.backend.clear_session() # Clear cached model
model = keras.Model(inputs, outputs) # Build new keras model
model.summary() # Print out model summary

model.compile("adam", "binary_crossentropy", metrics=["accuracy"]) # Compile built model with "adam", "binary_crossentropy", and metrics=["accuracy"]
model.fit(x_train, y_train, batch_size=64, epochs=10, validation_data=(x_val, y_val)) # Train the compiled model using model.fit() with batch_size=64, epochs=10, and validation_data=(x_val, y_val)
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, None)]            0
# _________________________________________________________________
# embedding (Embedding)        (None, None, 128)         128000
# _________________________________________________________________
# lstm (LSTM)                  (None, None, 128)         131584
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dense (Dense)                (None, 1)                 129
# =================================================================
# Total params: 391,297
# Trainable params: 391,297
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 12s 25ms/step - loss: 0.5555 - accuracy: 0.6920 - val_loss: 0.3960 - val_accuracy: 0.8234
# Epoch 2/10
# 391/391 [==============================] - 9s 24ms/step - loss: 0.3779 - accuracy: 0.8351 - val_loss: 0.3731 - val_accuracy: 0.8329
# Epoch 3/10
# 391/391 [==============================] - 9s 24ms/step - loss: 0.3607 - accuracy: 0.8409 - val_loss: 0.3680 - val_accuracy: 0.8339
# Epoch 4/10
# 391/391 [==============================] - 9s 24ms/step - loss: 0.3204 - accuracy: 0.8604 - val_loss: 0.3599 - val_accuracy: 0.8420
# Epoch 5/10
# 391/391 [==============================] - 9s 23ms/step - loss: 0.3093 - accuracy: 0.8654 - val_loss: 0.3552 - val_accuracy: 0.8475
# Epoch 6/10
# 391/391 [==============================] - 9s 23ms/step - loss: 0.2813 - accuracy: 0.8825 - val_loss: 0.3676 - val_accuracy: 0.8398
# Epoch 7/10
# 391/391 [==============================] - 9s 24ms/step - loss: 0.2791 - accuracy: 0.8824 - val_loss: 0.3601 - val_accuracy: 0.8391
# Epoch 8/10
# 391/391 [==============================] - 9s 23ms/step - loss: 0.2558 - accuracy: 0.8956 - val_loss: 0.3701 - val_accuracy: 0.8390
# Epoch 9/10
# 391/391 [==============================] - 9s 23ms/step - loss: 0.2478 - accuracy: 0.8956 - val_loss: 0.3760 - val_accuracy: 0.8282
# Epoch 10/10
# 391/391 [==============================] - 9s 24ms/step - loss: 0.2462 - accuracy: 0.8984 - val_loss: 0.3986 - val_accuracy: 0.8374
